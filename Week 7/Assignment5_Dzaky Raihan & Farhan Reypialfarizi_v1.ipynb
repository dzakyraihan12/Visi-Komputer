# %% [markdown]
# # **DZAKY RAIHAN AHMAD - 1301204316**
# # **FARHAN REYPIALFARIZI M - 1301200033**

# %% [markdown]
# [ASSIGNMENT 5] Cats vs Dogs Classification
#
# Fruit classification (10 Class).
#
# Dengan acuan source code cats vs dogs berikut. Lakukan klasifikasi  Fruit classification(10 Class), dari dataset ini https://www.kaggle.com/datasets/karimabdulnabi/fruit-classification10-class
#
# Kemudian modifikasi agar akurasi minimal mencapai 80%.

# %%
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
import matplotlib.pyplot as plt
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

# %%
local_zip = 'dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/'
train_dir = os.path.join(base_dir, 'MY_data/train')
test_dir = os.path.join(base_dir, 'MY_data/test')

# %%
train_apple = os.path.join(train_dir, 'Apple')
train_avocado = os.path.join(train_dir, 'avocado')
train_banana = os.path.join(train_dir, 'Banana')
train_cherry = os.path.join(train_dir, 'cherry')
train_kiwi = os.path.join(train_dir, 'kiwi')
train_mango = os.path.join(train_dir, 'mango')
train_orange = os.path.join(train_dir, 'orange')
train_pineapple = os.path.join(train_dir, 'pineapple')
train_strawberries = os.path.join(train_dir, 'strawberries')
train_watermelon = os.path.join(train_dir, 'watermelon')

# %%
test_apple = os.path.join(test_dir, 'apple')
test_avocado = os.path.join(test_dir, 'avocado')
test_banana = os.path.join(test_dir, 'banana')
test_cherry = os.path.join(test_dir, 'cherry')
test_kiwi = os.path.join(test_dir, 'kiwi')
test_mango = os.path.join(test_dir, 'mango')
test_orange = os.path.join(test_dir, 'orange')
test_pineapple = os.path.join(test_dir, 'pineapple')
test_strawberries = os.path.join(test_dir, 'stawberries')
test_watermelon = os.path.join(test_dir, 'watermelon')

# %%
train_datagen = ImageDataGenerator(
        rotation_range=15,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        width_shift_range=0.1,
        height_shift_range=0.1,
        rescale=1./255,
        validation_split=0.2
    )
test_datagen = ImageDataGenerator(
        rotation_range=15,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        width_shift_range=0.1,
        height_shift_range=0.1,
        rescale=1./255
    )

# %%
train_gen = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 2301 images belonging to 10 classes.

# %%
test_gen = test_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 1025 images belonging to 10 classes.

# %%
label = ['Apple', 'Banana', 'avocado', 'cherry', 'kiwi', 'mango', 'orange', 'pinenapple', 'strawberries', 'watermelon']

# %%
train=train_datagen.flow_from_directory(
    train_dir,
    classes=label,
    color_mode="rgb",
    batch_size=64,
    target_size=(256,256),
    class_mode="categorical",
    subset="training"
)
# Out:
# Found 1841 images belonging to 10 classes.

# %%
validation=train_datagen.flow_from_directory(
    train_dir,
    classes=label,
    color_mode="rgb",
    batch_size=64,
    target_size=(256,256),
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 460 images belonging to 10 classes.

# %%
test=test_datagen.flow_from_directory(
    test_dir,
    classes=list(map(lambda x:x.lower().replace("strawberries","strawberries"),label)),
    color_mode="rgb",
    batch_size=64,
    target_size=(256,256),
    class_mode="categorical"
)
# Out:
# Found 922 images belonging to 10 classes.

# %%
model = tf.keras.models.Sequential([
    layers.RandomRotation(0.1, input_shape=(256, 256, 3)),
    layers.RandomZoom(0.1),
    layers.RandomFlip(),
    layers.GaussianNoise(0.03),

    layers.Conv2D(32, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),
    
    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),
    
    layers.Conv2D(128, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),
    
    layers.Flatten(),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(len(label), activation='softmax')
])
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
callback_trigger=[
    callbacks.EarlyStopping(monitor="accuracy",patience=15,restore_best_weights=True),
    callbacks.ReduceLROnPlateau(factor=0.85,monitor="accuracy",patience=15)
]

# %%
history=model.fit(train,validation_data=validation,epochs=150,verbose=1, callbacks=callback_trigger)
# Out:
# Epoch 1/150
# 29/29 [==============================] - 120s 4s/step - loss: 2.5219 - accuracy: 0.2118 - val_loss: 2.2966 - val_accuracy: 0.1239 - lr: 0.0010
# Epoch 2/150
# 29/29 [==============================] - 109s 4s/step - loss: 1.9824 - accuracy: 0.3161 - val_loss: 2.5784 - val_accuracy: 0.1304 - lr: 0.0010
# Epoch 3/150
# 29/29 [==============================] - 120s 4s/step - loss: 1.8234 - accuracy: 0.3710 - val_loss: 2.9096 - val_accuracy: 0.1304 - lr: 0.0010
# Epoch 4/150
# 29/29 [==============================] - 418s 15s/step - loss: 1.7163 - accuracy: 0.3960 - val_loss: 3.0612 - val_accuracy: 0.1065 - lr: 0.0010
# Epoch 5/150
# 29/29 [==============================] - 857s 30s/step - loss: 1.5696 - accuracy: 0.4519 - val_loss: 3.0515 - val_accuracy: 0.1065 - lr: 0.0010
# Epoch 6/150
# 29/29 [==============================] - 117s 4s/step - loss: 1.5150 - accuracy: 0.4595 - val_loss: 3.3362 - val_accuracy: 0.1000 - lr: 0.0010
# Epoch 7/150
# 29/29 [==============================] - 486s 17s/step - loss: 1.4116 - accuracy: 0.4970 - val_loss: 3.4089 - val_accuracy: 0.1022 - lr: 0.0010
# Epoch 8/150
# 29/29 [==============================] - 1565s 53s/step - loss: 1.3711 - accuracy: 0.5057 - val_loss: 3.2791 - val_accuracy: 0.1217 - lr: 0.0010
# Epoch 9/150
# 29/29 [==============================] - 578s 20s/step - loss: 1.2980 - accuracy: 0.5166 - val_loss: 3.1717 - val_accuracy: 0.1304 - lr: 0.0010
# Epoch 10/150
# 29/29 [==============================] - 112s 4s/step - loss: 1.3001 - accuracy: 0.5443 - val_loss: 2.8562 - val_accuracy: 0.1283 - lr: 0.0010
# Epoch 11/150
# 29/29 [==============================] - 117s 4s/step - loss: 1.2547 - accuracy: 0.5535 - val_loss: 2.8224 - val_accuracy: 0.1630 - lr: 0.0010
# Epoch 12/150
# 29/29 [==============================] - 265s 9s/step - loss: 1.2581 - accuracy: 0.5530 - val_loss: 2.7584 - val_accuracy: 0.1761 - lr: 0.0010
# Epoch 13/150
# 29/29 [==============================] - 956s 34s/step - loss: 1.1834 - accuracy: 0.5676 - val_loss: 2.4885 - val_accuracy: 0.2109 - lr: 0.0010
# Epoch 14/150
# 29/29 [==============================] - 942s 22s/step - loss: 1.1732 - accuracy: 0.5807 - val_loss: 2.4382 - val_accuracy: 0.2674 - lr: 0.0010
# Epoch 15/150
# 29/29 [==============================] - 461s 16s/step - loss: 1.1676 - accuracy: 0.5910 - val_loss: 2.3123 - val_accuracy: 0.2609 - lr: 0.0010
# Epoch 16/150
# 29/29 [==============================] - 111s 4s/step - loss: 1.1558 - accuracy: 0.5823 - val_loss: 2.1950 - val_accuracy: 0.2978 - lr: 0.0010
- val_accuracy: 0.7674 - lr: 0.0010
# Epoch 133/150
# 29/29 [==============================] - 100s 3s/step - loss: 0.3535 - accuracy: 0.8848 - val_loss: 0.8050 - val_accuracy: 0.7783 - lr: 0.0010
# Epoch 134/150
# 29/29 [==============================] - 94s 3s/step - loss: 0.3497 - accuracy: 0.8762 - val_loss: 1.1162 - val_accuracy: 0.6935 - lr: 0.0010
# Epoch 135/150
# 29/29 [==============================] - 91s 3s/step - loss: 0.3321 - accuracy: 0.8843 - val_loss: 0.9613 - val_accuracy: 0.7217 - lr: 0.0010
# Epoch 136/150
# 29/29 [==============================] - 90s 3s/step - loss: 0.3174 - accuracy: 0.8821 - val_loss: 0.7722 - val_accuracy: 0.7761 - lr: 0.0010
# Epoch 137/150
# 29/29 [==============================] - 90s 3s/step - loss: 0.3115 - accuracy: 0.8854 - val_loss: 0.9791 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 138/150
# 29/29 [==============================] - 87s 3s/step - loss: 0.2944 - accuracy: 0.8990 - val_loss: 0.7640 - val_accuracy: 0.7804 - lr: 0.0010
# Epoch 139/150
# 29/29 [==============================] - 95s 3s/step - loss: 0.3099 - accuracy: 0.8968 - val_loss: 0.8986 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 140/150
# 29/29 [==============================] - 93s 3s/step - loss: 0.3201 - accuracy: 0.8870 - val_loss: 1.0168 - val_accuracy: 0.7326 - lr: 0.0010
# Epoch 141/150
# 29/29 [==============================] - 101s 3s/step - loss: 0.2811 - accuracy: 0.9044 - val_loss: 0.8272 - val_accuracy: 0.7630 - lr: 0.0010
# Epoch 142/150
# 29/29 [==============================] - 90s 3s/step - loss: 0.3078 - accuracy: 0.8968 - val_loss: 0.9528 - val_accuracy: 0.7348 - lr: 0.0010
# Epoch 143/150
# 29/29 [==============================] - 85s 3s/step - loss: 0.2975 - accuracy: 0.9049 - val_loss: 0.8875 - val_accuracy: 0.7413 - lr: 0.0010
# Epoch 144/150
# 29/29 [==============================] - 87s 3s/step - loss: 0.3088 - accuracy: 0.8886 - val_loss: 0.6687 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 145/150
# 29/29 [==============================] - 89s 3s/step - loss: 0.2990 - accuracy: 0.8935 - val_loss: 0.9268 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 146/150
# 29/29 [==============================] - 92s 3s/step - loss: 0.3044 - accuracy: 0.8973 - val_loss: 0.7331 - val_accuracy: 0.7783 - lr: 0.0010
# Epoch 147/150
# 29/29 [==============================] - 97s 3s/step - loss: 0.2758 - accuracy: 0.9011 - val_loss: 0.9818 - val_accuracy: 0.7304 - lr: 0.0010
# Epoch 148/150
# 29/29 [==============================] - 99s 3s/step - loss: 0.2867 - accuracy: 0.9066 - val_loss: 0.8123 - val_accuracy: 0.7587 - lr: 0.0010
# Epoch 149/150
# 29/29 [==============================] - 101s 3s/step - loss: 0.2760 - accuracy: 0.9087 - val_loss: 0.8314 - val_accuracy: 0.7891 - lr: 0.0010
# Epoch 150/150
# 29/29 [==============================] - 101s 3s/step - loss: 0.2836 - accuracy: 0.9087 - val_loss: 0.8361 - val_accuracy: 0.7739 - lr: 0.0010

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
import pandas as pd

predict_dir = os.path.join(base_dir, 'MY_data/predict')

# List all image files in the predict directory
image_files = [f for f in os.listdir(predict_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

# Create a DataFrame with the file names
df = pd.DataFrame({'filename': image_files, 'class': ['unknown'] * len(image_files)})

predict_datagen = ImageDataGenerator(rescale=1./255)

predict_generator = predict_datagen.flow_from_dataframe(
    df,
    directory=predict_dir,
    x_col='filename',
    y_col='class',
    class_mode=None,  # No labels in prediction mode
    target_size=(256, 256),
    color_mode="rgb",
    shuffle=False  # Set to False to ensure predictions are ordered
)
# Out:
# Found 48 validated image filenames.

# %%
# Generate predictions for the images in the predict folder
predictions = model.predict(predict_generator)

# Assuming you have a variable `classes` containing the class names
class_names = label

# Get the predicted class indices for each image
predicted_class_indices = predictions.argmax(axis=1)

# Map the predicted class indices to class names
predicted_class_names = [class_names[i] for i in predicted_class_indices]

# Print the results
for filename, predicted_class in zip(predict_generator.filenames, predicted_class_names):
    print(f"File: {filename}, Predicted Class: {predicted_class}")

# If you want to visualize the images along with predictions
# Note: This requires Matplotlib and PIL (Pillow) to be installed
import matplotlib.pyplot as plt
from PIL import Image

# Display the first few images with their predictions
num_images_to_display = 48

for i in range(min(num_images_to_display, len(predict_generator.filenames))):
    img_path = os.path.join(predict_dir, predict_generator.filenames[i])
    fig_size = (2, 2)
    plt.figure(figsize=fig_size)
    img = Image.open(img_path)
    plt.imshow(img)
    plt.title(f"Predicted Class: {predicted_class_names[i]}")
    plt.show()
# Out:
# 2/2 [==============================] - 1s 164ms/step
# File: img_421.jpeg, Predicted Class: mango
# File: 365.jpeg, Predicted Class: kiwi
# File: f2.jpeg, Predicted Class: strawberries
# File: 0.jpeg, Predicted Class: Apple
# File: img_41.jpeg, Predicted Class: avocado
# File: img_381.jpeg, Predicted Class: orange
# File: img_401.jpeg, Predicted Class: mango
# File: 66.jpeg, Predicted Class: pinenapple
# File: img_21.jpeg, Predicted Class: pinenapple
# File: 1.jpeg, Predicted Class: Apple
# File: img_01.jpeg, Predicted Class: avocado
# File: 011.jpeg, Predicted Class: watermelon
# File: img_411.jpeg, Predicted Class: mango
# File: 77.jpeg, Predicted Class: pinenapple
# File: 41.jpeg, Predicted Class: cherry
# File: 00.jpeg, Predicted Class: cherry
# File: img_11.jpeg, Predicted Class: avocado
# File: f5.jpeg, Predicted Class: strawberries
# File: 99.jpeg, Predicted Class: pinenapple
# File: img_191.jpeg, Predicted Class: Banana
# File: img_31.jpeg, Predicted Class: avocado
# File: img_241.jpeg, Predicted Class: orange
# File: 22.jpeg, Predicted Class: pinenapple
# File: 4.jpeg, Predicted Class: Banana
# File: img_171.jpeg, Predicted Class: Banana
# File: 321.jpeg, Predicted Class: kiwi
# File: 659.jpeg, Predicted Class: kiwi
# File: f7.jpeg, Predicted Class: cherry
# File: img_371.jpeg, Predicted Class: orange
# File: 012.jpeg, Predicted Class: watermelon
# File: 9.jpeg, Predicted Class: cherry
# File: 0122.jpeg, Predicted Class: watermelon
# File: 023.jpeg, Predicted Class: watermelon
# File: f0.jpeg, Predicted Class: strawberries
# File: 2.jpeg, Predicted Class: Banana
# File: img_141.jpeg, Predicted Class: Banana
# File: 65.jpeg, Predicted Class: cherry
# File: 202.jpeg, Predicted Class: kiwi
# File: img_301.jpeg, Predicted Class: mango
# File: 147.jpeg, Predicted Class: kiwi
# File: img_341.jpeg, Predicted Class: mango
# File: 0124.jpeg, Predicted Class: watermelon
# File: 33.jpeg, Predicted Class: pinenapple
# File: img_121.jpeg, Predicted Class: Banana
# File: img_361.jpeg, Predicted Class: orange
# File: 68.jpeg, Predicted Class: cherry
# File: f1.jpeg, Predicted Class: strawberries
# File: 3.jpeg, Predicted Class: Apple
